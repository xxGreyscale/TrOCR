# %%
from data.loader.custom_loader import CustomLoader

# Load the data
handwritten_df = CustomLoader(["../datasets/handwritten/augmented_v2/image_labels_dataset.csv"])
handwritten_df.generate_dataframe()
handwritten_df.get_dataframe().head()
# Out:
# File exists: ../datasets/handwritten/augmented_v2/image_labels_dataset.csv
# Encoding: utf-8
# Calculating max length: 100%|██████████| 129019/129019 [00:05<00:00, 23511.95it/s]
#                                            file_name  \
# 0  datasets\\handwritten\\augmented_v2\0001_fac_0...
# 1  datasets\\handwritten\\augmented_v2\0001_fac_0...
# 2  datasets\\handwritten\\augmented_v2\0001_fac_0...
# 3  datasets\\handwritten\\augmented_v2\0001_fac_0...
# 4  datasets\\handwritten\\augmented_v2\0001_fac_0...
#
#                                          text
# 0           Protokoll fört vid Upsala Sosial-
# 1     Demokratiska Ungdomsklubb konstituerade
# 2          möte Söndagen den 27 Desember 1903
# 3                                         § 1
# 4  Mötet öppnades af Herr Kasttello hvarefter

# %%
handwritten_df.generate_dataframe()
# Out:
# File exists: ../datasets/handwritten/augmented_v2/image_labels_dataset.csv
# Encoding: utf-8
# Calculating max length: 100%|██████████| 129019/129019 [00:05<00:00, 23287.52it/s]

# %%
handwritten_df.generate_histogram()
# Out:
# <Axes: title={'center': 'Histogram of Text Lengths'}, xlabel='Text Length', ylabel='Frequency'>

# %%
printed_data = CustomLoader(["../datasets/printed/150k/augmented/image_labels_dataset.csv"])
printed_data.generate_dataframe()
printed_data.get_dataframe().head()
# Out:
# File exists: ../datasets/printed/150k/augmented/image_labels_dataset.csv
# Encoding: Windows-1254
# Calculating max length: 100%|██████████| 111706/111706 [00:04<00:00, 23351.42it/s]
#                                            file_name  \
# 0  C:\\Users\\salim\\Desktop\\macos\\pythonProjec...
# 1  C:\\Users\\salim\\Desktop\\macos\\pythonProjec...
# 2  C:\\Users\\salim\\Desktop\\macos\\pythonProjec...
# 3  C:\\Users\\salim\\Desktop\\macos\\pythonProjec...
# 4  C:\\Users\\salim\\Desktop\\macos\\pythonProjec...
#
#                                                 text
# 0  ”Till Guds ära och till vårt rikes lyckliga fö...
# 1  \n\n=== Andra historiska byggnader ===\nSkytte...
# 2  I vissa andra språk, till exempel ryska och gr...
# 3                              Läst 26 januari 2009.
# 4  Sedan dess har det även blivit en andra sejour...

# %%
printed_data.generate_histogram()
# Out:
# <Axes: title={'center': 'Histogram of Text Lengths'}, xlabel='Text Length', ylabel='Frequency'>
