# %%
from data.loader.custom_loader import CustomLoader

# Load the data
data = CustomLoader("datasets/handwritten/augmented/image_labels_dataset.csv")
data.generate_dataframe()
# Out:
# File exists
# Encoding: utf-8
# Calculating max length: 100%|██████████| 129019/129019 [00:05<00:00, 23087.94it/s]

# %%
# Display the data
data.generate_histogram()
# Out:
# <Axes: title={'center': 'Histogram of Text Lengths'}, xlabel='Text Length', ylabel='Frequency'>

# %%
printed_data = CustomLoader("datasets/printed/augmented/image_labels_dataset.csv")
printed_data.generate_dataframe()
# Out:
# File exists
# Encoding: Windows-1254
# Calculating max length: 100%|██████████| 42702/42702 [00:01<00:00, 22805.28it/s]

# %%
printed_data.generate_histogram()
# Out:
# <Axes: title={'center': 'Histogram of Text Lengths'}, xlabel='Text Length', ylabel='Frequency'>
