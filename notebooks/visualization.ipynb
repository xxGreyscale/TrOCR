# %%
from data.loader.custom_loader import CustomLoader

# Load the data
path = ["..\\datasets\\handwritten\\augmented_v2\\image_labels_dataset.csv"]
handwritten_df = CustomLoader(path)
handwritten_df.generate_dataframe()
handwritten_df.get_dataframe().head()
# Out:
# File exists: ..\datasets\handwritten\augmented_v2\image_labels_dataset.csv
# Encoding: utf-8
# Calculating max length: 100%|██████████| 129019/129019 [00:05<00:00, 22994.04it/s]
#                                            file_name  \
# 0  datasets\\handwritten\\augmented_v2\0001_fac_0...
# 1  datasets\\handwritten\\augmented_v2\0001_fac_0...
# 2  datasets\\handwritten\\augmented_v2\0001_fac_0...
# 3  datasets\\handwritten\\augmented_v2\0001_fac_0...
# 4  datasets\\handwritten\\augmented_v2\0001_fac_0...
#
#                                          text
# 0           Protokoll fört vid Upsala Sosial-
# 1     Demokratiska Ungdomsklubb konstituerade
# 2          möte Söndagen den 27 Desember 1903
# 3                                         § 1
# 4  Mötet öppnades af Herr Kasttello hvarefter

# %%
# Visualize the first 5 images
handwritten_df.visualize_images(num_images=9)

# %%
# Load the data
kubhi_paths = ["../datasets/printed/Histrorical_News_Paper/combined.csv" ]
kubhist_df = CustomLoader(kubhi_paths)
kubhist_df.generate_dataframe()
kubhist_df.get_dataframe().head()
# Out:
# File exists: ../datasets/printed/Histrorical_News_Paper/combined.csv
# Encoding: utf-8
# Calculating max length: 100%|██████████| 8393/8393 [00:00<00:00, 22727.02it/s]
#                                            file_name  \
# 0  datasets/printed/Histrorical_News_Paper/TEST_D...
# 1  datasets/printed/Histrorical_News_Paper/TEST_D...
# 2  datasets/printed/Histrorical_News_Paper/TEST_D...
# 3  datasets/printed/Histrorical_News_Paper/TEST_D...
# 4  datasets/printed/Histrorical_News_Paper/TEST_D...
#
#                                         text
# 0                                denna ſekt.
# 1             ﻿Antiomianer kallas ſå af Gre=
# 2          De antaga ej goda gerningar ſåſom
# 3  nödwändiga medel till ſaligheten, och på=
# 4        ſtå, att de utwalde ingenting kunna

# %%
kubhist_df.visualize_images(num_images=9, padding=[25,3])

# %%
two_fifty_k_path = ["../datasets/printed/250k/augmented/image_labels_dataset.csv"]
two_fifty_k_df = CustomLoader(two_fifty_k_path)
two_fifty_k_df.generate_dataframe()
two_fifty_k_df.get_dataframe().head()
# Out:
# File exists: ../datasets/printed/250k/augmented/image_labels_dataset.csv
# Encoding: utf-8
# Calculating max length: 100%|██████████| 139345/139345 [00:06<00:00, 22882.62it/s]
#                                            file_name  \
# 0  datasets\printed\250k\augmented/images/image_0...
# 1  datasets\printed\250k\augmented/images/image_0...
# 2  datasets\printed\250k\augmented/images/image_0...
# 3  datasets\printed\250k\augmented/images/image_0...
# 4  datasets\printed\250k\augmented/images/image_0...
#
#                                                 text
# 0   24 april – Nils Åsblom, 67, svensk skådespelare.
# 1  De gjorde 1973 ledmotivet till Bond-filmen Lev...
# 2  Djupa floddalar bidrar till att ge bergen ett ...
# 3  De tidigare militära anläggningarna är en del ...
# 4  1839 – Fartyget "Mary Ann" under kapten Nils W...

# %%
two_fifty_k_df.visualize_images(num_images=9, padding=[42,4])
